# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\PC2\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pd = pd.read_csv('./fact.csv')
# Out:
# C:\Users\PC2\AppData\Local\Temp\ipykernel_22220\1118722517.py:1: DtypeWarning: Columns (3,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd = pd.read_csv('./fact.csv')

# %%
pd.head(2)
# Out:
#    match_num  winner_id  winner_seed winner_entry      winner_name  \
# 0        270     112411          NaN          NaN       Doug Smith
# 1        271     126914          NaN          NaN  Louis Pretorius
#
#   winner_hand  winner_ht winner_ioc  winner_age  loser_id  ...  l_bpSaved  \
# 0           U        NaN        AUS         NaN    110196  ...        NaN
# 1           R        NaN        RSA         NaN    209536  ...        NaN
#
#   l_bpFaced winner_rank winner_rank_points  loser_rank loser_rank_points  \
# 0       NaN         NaN                NaN         NaN               NaN
# 1       NaN         NaN                NaN         NaN               NaN
#
#    spectator avg_ticket_price  match_expenses tourney
# 0    10006.0           122.32        989177.0       0
# 1    13543.0           174.07        836293.2       0
#
# [2 rows x 47 columns]

# %%
pd.shape
# Out:
# (941649, 47)

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941649 entries, 0 to 941648
# Data columns (total 47 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   match_num           941649 non-null  int64
#  1   winner_id           941649 non-null  int64
#  2   winner_seed         399896 non-null  float64
#  3   winner_entry        156231 non-null  object
#  4   winner_name         941649 non-null  object
#  5   winner_hand         922284 non-null  object
#  6   winner_ht           652975 non-null  float64
#  7   winner_ioc          941641 non-null  object
#  8   winner_age          929026 non-null  float64
#  9   loser_id            941649 non-null  int64
#  10  loser_seed          205049 non-null  float64
#  11  loser_entry         277467 non-null  object
#  12  loser_name          941649 non-null  object
#  13  loser_hand          920820 non-null  object
#  14  loser_ht            542290 non-null  float64
# ...

# %%
pd.describe()
# Out:
#            match_num      winner_id    winner_seed      winner_ht  \
# count  941649.000000  941649.000000  399896.000000  652975.000000
# mean       86.320185  115160.853737       4.827038     184.028200
# std       142.004429   29304.075210       3.734860       7.910491
# min         1.000000  100001.000000       1.000000       3.000000
# 25%        11.000000  102610.000000       2.000000     180.000000
# 50%        22.000000  104527.000000       4.000000     183.000000
# 75%       103.000000  106329.000000       7.000000     188.000000
# max      1701.000000  213703.000000      35.000000     211.000000
#
#           winner_age       loser_id     loser_seed       loser_ht  \
# count  929026.000000  941649.000000  205049.000000  542290.000000
# mean       24.057836  117657.922751       5.576092     183.930321
# std         3.978166   31299.789465       4.047703       8.095944
# min        14.000000  100001.000000       1.000000       3.000000
# ...

# %%
#unique values
pd['winner_id'].nunique()
# Out:
# 18938

# %%
# Check for missing values
pd.isnull().sum()
# Out:
# match_num                  0
# winner_id                  0
# winner_seed           541753
# winner_entry          785418
# winner_name                0
# winner_hand            19365
# winner_ht             288674
# winner_ioc                 8
# winner_age             12623
# loser_id                   0
# loser_seed            736600
# loser_entry           664182
# loser_name                 0
# loser_hand             20829
# loser_ht              399359
# loser_ioc                 81
# loser_age              27027
# score                    154
# best_of                    0
# round                      0
# minutes               734503
# w_ace                 727479
# w_df                  727480
# w_svpt                727480
# w_1stIn               727480
# w_1stWon              727480
# w_2ndWon              727480
# w_SvGms               727482
# w_bpSaved             727480
# w_bpFaced             727480
# l_ace                 727480
# l_df                  727479
# ...
