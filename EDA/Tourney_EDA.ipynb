# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd = pd.read_csv('../cleaning/tourney.csv')
# Out:
# C:\Users\PC2\AppData\Local\Temp\ipykernel_13936\3079029189.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd = pd.read_csv('../cleaning/tourney.csv')

# %%
pd.head(2)
# Out:
#    tourney tourney_id tourney_name surface draw_size tourney_level  \
# 0        0  1968-2029       Dublin   Grass      32.0             A
# 1        0  1968-2029       Dublin   Grass      32.0             A
#
#            tourney_timestamp
# 0  1968-07-08 00:00:00+00:00
# 1  1968-07-08 00:00:00+00:00

# %%
pd.shape
# Out:
# (941649, 7)

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941649 entries, 0 to 941648
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   tourney            941649 non-null  int64
#  1   tourney_id         941649 non-null  object
#  2   tourney_name       941649 non-null  object
#  3   surface            937020 non-null  object
#  4   draw_size          940814 non-null  object
#  5   tourney_level      941649 non-null  object
#  6   tourney_timestamp  941649 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 50.3+ MB

# %%
pd.describe()
# Out:
#              tourney
# count  941649.000000
# mean    16746.509850
# std      9084.535759
# min         0.000000
# 25%      8875.000000
# 50%     17083.000000
# 75%     24655.000000
# max     31377.000000

# %%
# Check for missing values
pd.isnull().sum()
# Out:
# tourney                 0
# tourney_id              0
# tourney_name            0
# surface              4629
# draw_size             835
# tourney_level           0
# tourney_timestamp       0
# dtype: int64

# %%
#sns plot missing values
sns.heatmap(pd.isnull(), cbar=False, cmap='viridis')
#sns plot missing values
plt.title('Missing Values in Dataset')
plt.show()

# %%
#calculate percentage of missing values
missing_percentage = pd.isnull().sum() / len(pd) * 100
missing_percentage = missing_percentage[missing_percentage > 0]
missing_percentage = missing_percentage.sort_values(ascending=False)
missing_percentage = missing_percentage.reset_index()
missing_percentage.columns = ['Column Name', 'Missing Percentage']
#plot missing values
plt.figure(figsize=(10, 6))
sns.barplot(x='Missing Percentage', y='Column Name', data=missing_percentage, palette='viridis')
# Out:
# <Axes: xlabel='Missing Percentage', ylabel='Column Name'>

# %%
missing_percentage
# Out:
#   Column Name  Missing Percentage
# 0     surface            0.491584
# 1   draw_size            0.088674

# %%
#sns plot missing values
sns.heatmap(pd.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values in Dataset')
plt.show()

# %%
import pandas as pds
pd2= pds.read_csv('../datasets/cleaned/tourney.csv')

# %%
#sns plot missing values
sns.heatmap(pd2.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values in Dataset')
plt.show()
